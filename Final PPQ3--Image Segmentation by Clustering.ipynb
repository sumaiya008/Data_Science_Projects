# %% [markdown]
# # Final PPQ3--Image Segmentation by Clustering
#
# Lets do some **unsupervised** learning. We are going to segment an image into regions via kmeans clustering.
#
# url = "https://bit.ly/coloredpowders"
#
#
# ## Import the image
#
# Use scipy.ndimage.imread to get a 275 × 183 (rows and columns) x 3 (colors image)

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
from imageio import imread
image = imread('https://bit.ly/coloredpowders')
plt.imshow(image)

# %% [markdown]
# ## Reformat image
#
# Reshape the data so it has 275*183 rows and 3 columns. We are used to columns as being features and rows (pixels) as being different examples. This does that.

# %%
df=pd.DataFrame(image.reshape(-1, 3),columns=['r', 'g', 'b'])
df.head()
# Out:
#      r    g    b
# 0  194  164  187
# 1  255   89   59
# 2  141  255  129
# 3  111  108  255
# 4  130  115  120

# %%
df.shape
# Out:
# (47300, 3)

# %% [markdown]
# ## EDA with the first 2 columns
#
# We can't look at all the data but lets look at some

# %%
import seaborn as sns
plt.figure(figsize=(8,8))
plt.subplot(221)
sns.histplot(df.r , color ='purple', kde=True)

plt.subplot(222)
sns.histplot(df.b , color ='red', kde=True)
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <AxesSubplot:xlabel='b', ylabel='Count'>

# %% [markdown]
# ## Find three region map
#
# Run K-means clustering on the data with k=3 to get three clusters

# %%
# Import KMeans
from sklearn.cluster import KMeans
 
# Create a KMeans instance with 3 clusters: model
model = KMeans(n_clusters=3)
 
# Fit model to points
model.fit(df)
 
# Determine the cluster labels of new_points: labels
labels = model.predict(df)
 
# Print cluster labels of new_points
print(labels)
# Out:
# [2 1 0 ... 1 0 2]

# %% [markdown]
# ##  Reshape into an Image
# Reshape cluster labels 0,1,3 for all the data so it is a 275 × 183 image. Rescale (multiply by 1/3).

# %% [markdown]
# ##  Show labels
#
# Make the labels an image and use a qualitative colormap (cheatshets) to see them as distinct colors.

# %% [markdown]
# ##  Cluster again
#
# Set k=4,5 and show the corresponding images

# %%
rubric="""* 02pts Import the image
* 05pts Reformat image
* 05pts EDA with the first 2 columns
* 05pts Find three region map
* 04pts Reshape into an Image
* 04pts Show labels
* 05pts Cluster again
"""
thing = sum([int(line[2:4]) for line in rubric.split('\n') if line])
print(thing)
# Out:
# 30
