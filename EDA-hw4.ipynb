# %% [markdown]
# ## Student Performanece at school - EDA
#
# Student Performance Data was obtained in a survey of students' math course in secondary school. This Student Performance Dataset was choose from https://www.kaggle.com/datasets/devansodariya/student-performance-data.
#
# I have tried to find correlations between some data from dataset, I have done some statistical analysis as well as augmented them with plots and visualized them.

# %%
# Importing differnt packeges and library

import numpy as np
import pandas as pd
import sklearn as skl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Importing dataset

st_data = pd.read_csv('student_data.csv')

# %% [markdown]
# ##  Basic understanding Dataset

# %%
st_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
type(st_data)
# Out:
# pandas.core.frame.DataFrame

# %%
st_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# checking for unique values

st_data.nunique()
# Out:
# school         2
# sex            2
# age            8
# address        2
# famsize        2
# Pstatus        2
# Medu           5
# Fedu           5
# Mjob           5
# Fjob           5
# reason         4
# guardian       3
# traveltime     4
# studytime      4
# failures       4
# schoolsup      2
# famsup         2
# paid           2
# activities     2
# nursery        2
# higher         2
# internet       2
# romantic       2
# famrel         5
# freetime       5
# goout          5
# Dalc           5
# Walc           5
# health         5
# absences      34
# G1            17
# G2            17
# G3            18
# dtype: int64

# %%
st_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
plt.figure(figsize=(20,10))
st_data.boxplot()
# Out:
# <AxesSubplot: >

# %% [markdown]
#  Ploting histograms and bar charts for variables of the data.

# %%
plt.hist(st_data.school);
plt.title("Number of students going to diffrent schools");

# %% [markdown]
# This is showing only two different schools performance is recorded in dataset.

# %%
plt.hist(st_data.sex);

# %% [markdown]
# It's showing there is more Female student then Male student.

# %%
plt.boxplot(st_data.age);

# %% [markdown]
# This boxplot is showing most of students are age 16-18.

# %% [markdown]
# ### Checking Data Types

# %%
st_data.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# dtype: object

# %%
# Seperating diffrent data types

col_1  = st_data.select_dtypes(include=np.object, exclude=np.number)
col_1
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_9132\1857586536.py:3: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   col_1  = st_data.select_dtypes(include=np.object, exclude=np.number)
#     school sex address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0       GP   F       U     GT3       A   at_home   teacher  course   mother
# 1       GP   F       U     GT3       T   at_home     other  course   father
# 2       GP   F       U     LE3       T   at_home     other   other   mother
# 3       GP   F       U     GT3       T    health  services    home   mother
# 4       GP   F       U     GT3       T     other     other    home   father
# ..     ...  ..     ...     ...     ...       ...       ...     ...      ...
# ...

# %%
col_1.columns
# Out:
# Index(['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob',
#        'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities',
#        'nursery', 'higher', 'internet', 'romantic'],
#       dtype='object')

# %%
col_2 = st_data.select_dtypes(include=np.number, exclude=np.object)

col_2
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_9132\2273590478.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   col_2 = st_data.select_dtypes(include=np.number, exclude=np.object)
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0     18     4     4           2          2         0       4         3
# 1     17     1     1           1          2         0       5         3
# 2     15     1     1           1          2         3       4         3
# 3     15     4     2           1          3         0       3         2
# 4     16     3     3           1          2         0       4         3
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# ...

# %%
col_2.columns
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures', 'famrel',
#        'freetime', 'goout', 'Dalc', 'Walc', 'health', 'absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %%
# making bar chart 

for i, col in enumerate(col_1.columns):
    plt.figure(i, figsize=(3,3))
    sns.countplot(x=col, data=col_1)
    
    plt.show()

# %%
# making histrogram

for i, col in enumerate(col_2.columns):
    plt.figure(i, figsize=(3,3))
    sns.kdeplot(x=col, data=col_2)
    
    plt.show()

# %%
 sns.pairplot(data = col_2)

# %% [markdown]
# Now i want to understand from dataset that either girls are doing good in performance or boys. For that first let's make a subset Final grade then we will compare it with other variables.

# %% [markdown]
# ### Final Grade

# %%
st_data['Final_G'] = (st_data["G1"]+st_data["G2"]+st_data["G3"])/3

# %%
st_data['Final_G'].head()
# Out:
# 0     5.666667
# 1     5.333333
# 2     8.333333
# 3    14.666667
# 4     8.666667
# Name: Final_G, dtype: float64

# %% [markdown]
# ### Study time Vs Grades

# %%
sns.barplot(x="studytime",y="Final_G", hue="sex", data=st_data, ci=False)
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_9132\1411557138.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="studytime",y="Final_G", hue="sex", data=st_data, ci=False)
# <AxesSubplot: xlabel='studytime', ylabel='Final_G'>

# %% [markdown]
# Male students are studying more and doing better on tests.

# %%
sns.scatterplot(st_data, x="absences",y='Final_G',hue='sex')
# Out:
# <AxesSubplot: xlabel='absences', ylabel='Final_G'>

# %% [markdown]
# Studens who have less absences are better in grade performance.

# %% [markdown]
# ### Failures Vs Grade

# %%
sns.barplot(x="failures", y="Final_G", hue="sex", data=st_data, ci=False)
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_9132\2038518375.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="failures", y="Final_G", hue="sex", data=st_data, ci=False)
# <AxesSubplot: xlabel='failures', ylabel='Final_G'>

# %% [markdown]
# Male students have less failures.

# %% [markdown]
# ### School Vs Grade

# %%
sns.barplot(x="school", y="Final_G", hue="sex", data=st_data, ci=False)
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_9132\1690944823.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="school", y="Final_G", hue="sex", data=st_data, ci=False)
# <AxesSubplot: xlabel='school', ylabel='Final_G'>

# %% [markdown]
# GP school have more better grades and male students are on high point.

# %% [markdown]
# ### Travel time Vs Grade

# %%
sns.barplot(x="traveltime", y="Final_G", hue="sex", data=st_data, ci=False)
# Out:
# C:\Users\sumai\AppData\Local\Temp\ipykernel_9132\1665776206.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', False)` for the same effect.
#
#   sns.barplot(x="traveltime", y="Final_G", hue="sex", data=st_data, ci=False)
# <AxesSubplot: xlabel='traveltime', ylabel='Final_G'>

# %% [markdown]
# Students who lives nearby school are doing good. In this case also Male students have better grades.

# %% [markdown]
# ## Summery

# %% [markdown]
# From overall observation statistically we can say Male Students are scored better than Female Students.
#
# And student who study more, have less absences and lives near by school are doing good as well.
