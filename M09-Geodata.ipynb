# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series, read_csv
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')
mpl.rcParams['figure.figsize'] = (10, 6)

# Boiler plate imports 
# I copy paste and remove later
import numpy as np
# Libraries I usually need
import pandas as pd
import scipy as sp
import scipy.stats as stats
from pandas import DataFrame, Series

# %%
from cartopy import crs as ccrs
from cartopy import feature as cfeature

# %%
fig = plt.figure(figsize=(11,8.5))
ax = plt.subplot(1,1,1, projection=ccrs.PlateCarree(central_longitude=-75))
ax.set_title("Plate Carree projection")
# Out:
# Text(0.5, 1.0, 'Plate Carree projection')

# %%
fig = plt.figure(figsize=(11,8.5))
ax = plt.subplot(1,1,1, projection=ccrs.PlateCarree(central_longitude=-75))
ax.set_title("Plate Carree projection")
ax.coastlines()

# %%
fig = plt.figure(figsize=(11,8.5))
ax = plt.subplot(1,1,1, projection=ccrs.PlateCarree(central_longitude=-75))
ax.set_title("Plate Carree projection")
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='brown')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/io/__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_0_boundary_lines_land.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
fig = plt.figure(figsize=(11,8.5))
ax = plt.subplot(1,1,1, projection=ccrs.PlateCarree(central_longitude=-75))
ax.set_title("Plate Carree projection")
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='brown')
ax.add_feature(cfeature.STATES, linewidth=0.3, edgecolor='blue')
# Out:
# /opt/tljh/user/lib/python3.7/site-packages/cartopy/io/__init__.py:260: DownloadWarning: Downloading: https://naciscdn.org/naturalearth/110m/cultural/ne_110m_admin_1_states_provinces_lakes.zip
#   warnings.warn('Downloading: {}'.format(url), DownloadWarning)

# %%
fig = plt.figure(figsize=(11,8.5))
projMoll = ccrs.Mollweide(central_longitude=0)
ax = plt.subplot(1,1,1, projection = projMoll)
ax.set_title("Mollweide Projection")
# Out:
# Text(0.5, 1.0, 'Mollweide Projection')

# %%
fig = plt.figure(figsize=(11,8.5))
projMoll = ccrs.Mollweide(central_longitude=0)
ax = plt.subplot(1,1,1, projection = projMoll)
ax.set_title("Mollweide Projection")
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='blue')

# %%
fig = plt.figure(figsize=(11,8.5))
projMoll = ccrs.Mollweide(central_longitude=0)
ax = plt.subplot(1,1,1, projection = projMoll)
ax.set_title("Mollweide Projection")
ax.coastlines()
ax.add_feature(cfeature.BORDERS, linewidth=0.5, edgecolor='blue')
ax.stock_img()
